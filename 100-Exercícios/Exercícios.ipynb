# %%
from dic import vimeo
import pprint

# você precisa chegar em:
# videos = [
#     {'uri': video_uri, 'nome': nome_video, 'duracao': duracao, 'link540p': link540p, 'link720p': link720p, 'link1080p': link1080p},
# ]

videos = []
show = []
for item in vimeo:
    if item == 'data':
        for items in vimeo[item]:
            
            uri = items['uri']
            nome = items['name']
            duracao = items['duration']
            down = items['download']
            link = items['link']
            link720p = ''
            link540p = ''
            link1080p = ''

            for item in down:
                # print(item['rendition'])
                if item['rendition'] == '720p':
                    link720p = items['link']
                elif item['rendition'] == '540p':
                    link540p = items['link']
                elif item['rendition'] == '1080p':
                    link1080p = items['link']
            
            videos.append({
                'uri': uri,
                'nome': nome,
                'duracao': duracao,
                'link720p': link720p,
                'link540p': link540p,
                'link1080p': link1080p,
            })
# pprint.pprint(videos)
show = [print(f'{item}') for item in videos]
# Out:
# {'uri': '/videos/210375279', 'nome': 'Aula 2.3', 'duracao': 160, 'link720p': 'https://vimeo.com/210375279', 'link540p': 'https://vimeo.com/210375279', 'link1080p': ''}
# {'uri': '/videos/210374410', 'nome': 'Aula 2.2', 'duracao': 122, 'link720p': 'https://vimeo.com/210374410', 'link540p': 'https://vimeo.com/210374410', 'link1080p': ''}
# {'uri': '/videos/210373284', 'nome': 'Aula 2.1', 'duracao': 186, 'link720p': 'https://vimeo.com/210373284', 'link540p': 'https://vimeo.com/210373284', 'link1080p': ''}
# {'uri': '/videos/210365639', 'nome': 'Aula 3.4', 'duracao': 200, 'link720p': 'https://vimeo.com/210365639', 'link540p': 'https://vimeo.com/210365639', 'link1080p': ''}
# {'uri': '/videos/210364466', 'nome': 'Aula 1.6', 'duracao': 147, 'link720p': 'https://vimeo.com/210364466', 'link540p': 'https://vimeo.com/210364466', 'link1080p': ''}
# {'uri': '/videos/210349630', 'nome': 'Aula 1.5', 'duracao': 103, 'link720p': 'https://vimeo.com/210349630', 'link540p': 'https://vimeo.com/210349630', 'link1080p': ''}
# {'uri': '/videos/210348003', 'nome': 'Aula 1.4', 'duracao': 163, 'link720p': 'https://vimeo.com/210348003', 'link540p': 'https://vimeo.com/210348003', 'link1080p': ''}
# {'uri': '/videos/210346986', 'nome': 'Aula 1.3', 'duracao': 88, 'link720p': 'https://vimeo.com/210346986', 'link540p': 'https://vimeo.com/210346986', 'link1080p': ''}
# {'uri': '/videos/210345205', 'nome': 'Aula 1.2', 'duracao': 165, 'link720p': 'https://vimeo.com/210345205', 'link540p': 'https://vimeo.com/210345205', 'link1080p': ''}
# {'uri': '/videos/210341989', 'nome': 'Aula 1.1', 'duracao': 133, 'link720p': 'https://vimeo.com/210341989', 'link540p': 'https://vimeo.com/210341989', 'link1080p': ''}

# %%
import pandas as pd

informacoes = [
    (1, 'NATHANIEL FORD', 'GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 167411.18, 0.0, 400184.25, None, 567595.43, 567595.43, 2011, '', 'San Francisco', ''), 
    (2, 'GARY JIMENEZ', 'CAPTAIN III (POLICE DEPARTMENT)', 155966.02, 245131.88, 137811.38, None, 538909.28, 538909.28, 2011, '', 'San Francisco', ''), (3, 'ALBERT PARDINI', 'CAPTAIN III (POLICE DEPARTMENT)', 212739.13, 106088.18, 16452.6, None, 335279.91, 335279.91, 2011, '', 'San Francisco', ''), (4, 'CHRISTOPHER CHONG', 'WIRE ROPE CABLE MAINTENANCE MECHANIC', 77916.0, 56120.71, 198306.9, None, 332343.61, 332343.61, 2011, '', 'San Francisco', ''), (5, 'PATRICK GARDNER', 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)', 134401.6, 9737.0, 182234.59, None, 326373.19, 326373.19, 2011, '', 'San Francisco', ''), (6, 'DAVID SULLIVAN', 'ASSISTANT DEPUTY CHIEF II', 118602.0, 8601.0, 189082.74, None, 316285.74, 316285.74, 2011, '', 'San Francisco', ''), (7, 'ALSON LEE', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 92492.01, 89062.9, 134426.14, None, 315981.05, 315981.05, 2011, '', 'San Francisco', ''), (8, 'DAVID KUSHNER', 'DEPUTY DIRECTOR OF INVESTMENTS', 256576.96, 0.0, 51322.5, None, 307899.46, 307899.46, 2011, '', 'San Francisco', ''), (9, 'MICHAEL MORRIS', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 176932.64, 86362.68, 40132.23, None, 303427.55, 303427.55, 2011, '', 'San Francisco', ''), (10, 'JOANNE HAYES-WHITE', 'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 285262.0, 0.0, 17115.73, None, 302377.73, 302377.73, 2011, '', 'San Francisco', '')]

colunas = []
nome = []
cargo = []
resposta = []

descricao = (
    ('Id', "<class 'int'>", None, 10, 10, 0, True), 
    ('EmployeeName', "<class 'str'>", None, 65536, 65536, 0, True), 
    ('JobTitle', "<class 'str'>", None, 65536, 65536, 0, True), 
    ('BasePay', "<class 'float'>", None, 54, 54, 0, True), 
    ('OvertimePay', "<class 'float'>", None, 54, 54, 0, True), 
    ('OtherPay', "<class 'float'>", None, 54, 54, 0, True), 
    ('Benefits', "<class 'float'>", None, 54, 54, 0, True), 
    ('TotalPay', "<class 'float'>", None, 54, 54, 0, True), 
    ('TotalPayBenefits', "<class 'float'>", None, 54, 54, 0, True), 
    ('Year', "<class 'int'>", None, 10, 10, 0, True), 
    ('Notes', "<class 'str'>", None, 65536, 65536, 0, True), 
    ('Agency', "<class 'str'>", None, 65536, 65536, 0, True), 
    ('Status', "<class 'str'>", None, 65536, 65536, 0, True)
)

colunas = [item[0] for item in descricao]

tabela = pd.DataFrame.from_records(informacoes, columns=colunas)
# display(tabela)

nome = [item[1] for item in informacoes]
cargo = [item[2] for item in informacoes]

print('RH, segue a lista dos funcionários:')
resposta = [(print(f'Nome: {nome[i]}'), print(f'Cargo: {cargo[i]}')) for i, item in enumerate(nome)]
# Out:
# RH, segue a lista dos funcionários:
# Nome: NATHANIEL FORD
# Cargo: GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# Nome: GARY JIMENEZ
# Cargo: CAPTAIN III (POLICE DEPARTMENT)
# Nome: ALBERT PARDINI
# Cargo: CAPTAIN III (POLICE DEPARTMENT)
# Nome: CHRISTOPHER CHONG
# Cargo: WIRE ROPE CABLE MAINTENANCE MECHANIC
# Nome: PATRICK GARDNER
# Cargo: DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# Nome: DAVID SULLIVAN
# Cargo: ASSISTANT DEPUTY CHIEF II
# Nome: ALSON LEE
# Cargo: BATTALION CHIEF, (FIRE DEPARTMENT)
# Nome: DAVID KUSHNER
# Cargo: DEPUTY DIRECTOR OF INVESTMENTS
# Nome: MICHAEL MORRIS
# Cargo: BATTALION CHIEF, (FIRE DEPARTMENT)
# Nome: JOANNE HAYES-WHITE
# Cargo: CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)

# %%
faturamento = {
    'jan': 'R$ 95.141,98',
    'fev': 'R$ 95.425,16',
    'mar': 'R$ 89.716,31',
    'abr': 'R$ 78.459,99',
    'mai': 'R$ 71.087,28',
    'jun': 'R$ 83.911,06',
    'jul': 'R$ 56.467,26',
    'ago': 'R$ 88.513,58',
    'set': 'R$ 66.552,49',
    'out': 'R$ 80.164,07',
    'nov': 'R$ 66.964,33',
    'dez': 'R$ 71.525,25',
}


# percorrer cada item (mês) do dicionario
# para cada mês eu vou:
    # vou transformar o valor em número
    # calcular o imposto mensal
    # calcular o imposto trimestral
    # construir o resultado
